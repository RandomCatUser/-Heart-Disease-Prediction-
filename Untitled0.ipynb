# %% [markdown]
# # Heart Disease Prediction
# Cloning the repository to access data and scripts.

# %%
# !pip install pandas

# %%
import os
repo_name = '-Heart-Disease-Prediction-'
if os.path.exists(repo_name):
    os.chdir(repo_name)
    print(f"Changed directory to: {os.getcwd()}")
else:
    # !git clone https://github.com/RandomCatUser/-Heart-Disease-Prediction-.git
    os.chdir(repo_name)
    print(f"Cloned and changed directory to: {os.getcwd()}")
# Out:
# Changed directory to: /content/-Heart-Disease-Prediction-

# %%
import os
# List files inside the cloned repository to find the dataset and training script
print(f"Current directory: {os.getcwd()}")
print("Files in repository:", os.listdir())
# Out:
# Current directory: c:\projects\Heart attack ditector
# Files in repository: ['.git', '.qodo', 'api.py', 'app.py', 'config.py', 'dashboard.py', 'data', 'explain.py', 'LICENSE', 'models', 'notebooks', 'predict.py', 'README.md', 'requirements.txt', 'train.py', 'Untitled0.ipynb', 'utils.py']

# %%
# Install requirements and run the training script
if os.path.exists('requirements.txt'):
    # !pip install -r requirements.txt

if os.path.exists('train.py'):
    print("Starting training...")
    # !python train.py
else:
    print("train.py not found in the current directory.")
# Out:
# ...
#   Using cached pandas-2.2.2.tar.gz (4.4 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
# Starting training...
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [12 lines of output]
# ...

# %%
# Verify if the model was saved successfully
if os.path.exists('models/heart_model.pkl'):
    print("Training complete! Model saved at models/heart_model.pkl")
else:
    print("Training might still be in progress or failed to save the model file.")
# Out:
# Training complete! Model saved at models/heart_model.pkl

# %% [markdown]
# ### Model Testing
# Now we will run a test script to verify the model's prediction capabilities.

# %%
if os.path.exists('predict.py'):
    print("Running a test prediction...")
    # Running the prediction script which typically handles sample input
    # !python predict.py
else:
    print("predict.py not found. Let's create a manual test.")
    import pickle
    import pandas as pd

    # Manual test if script isn't straightforward
    with open('models/heart_model.pkl', 'rb') as f:
        model = pickle.load(f)

    # Creating a dummy sample based on standard heart disease features
    sample_data = pd.DataFrame([[52, 1, 0, 125, 212, 0, 1, 168, 0, 1.0, 2, 2, 3]],
                               columns=['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal'])

    prediction = model.predict(sample_data)
    print(f"Manual Test Prediction for sample: {prediction[0]}")
# Out:
# Running a test prediction...
# Traceback (most recent call last):
#   File "c:\projects\Heart attack ditector\predict.py", line 9, in <module>
#     import pandas as pd
# ModuleNotFoundError: No module named 'pandas'
